# %%
# %config Completer.use_jedi = False

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
import csv

# %%
# Get ticker list

# This is specifically for the small/medium cap Healthcare sector with stock price between 10-50
# on the date of 2/26/2021.

def get_tickers():

    tickers = []
    urls = []
    X = [x for x in range(0, 1001, 100)] # Since we know there are 5 to start

    for x in X:
        url = f'https://finance.yahoo.com/screener/unsaved/dc285ff9-d928-4d6f-af8c-91a4f115eb22?count=100&dependentField=sector&dependentValues=Healthcare&offset={x}'
        urls.append(url)


    for url in urls:
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'lxml')
        tables = soup.find_all('tr')[1:]

        # curr_table = tables[0]

        # data = float(curr_table.find_all('td', attrs={'aria-label': 'Price (Intraday)'})[0].text)

        # print(data)
        # data = curr_table.find_all('td', attrs={'aria-label': 'Symbol'})[0].text

        for i in range(len(tables)):
            curr_table = tables[i]
            name = curr_table.find_all('td', attrs={'aria-label': 'Symbol'})[0].text

            tickers.append(name)


    return tickers

# %%
tickers = get_tickers()

# %%
ticker_series = pd.Series(data=tickers)

# %%
ticker_series.to_csv('HealthCareTickers.csv', index=False)

# %%
# Add in new date data

def get_df(tickers, verbose=1):
    """
    Input a list of tickers, get out the daily stock data
    for that ticker since Jan 2, 2020. This include the date,
    open, close, high, low and volume for each ticker given.
    The data is organized by data ascending and grouped by each ticker.
    
    Set verbose=1 if you would like an update after every ticker data has been downloaded.
    Otherwise, set verbose=0
    """
    
    columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Ticker']

    df = pd.DataFrame(columns=columns)
    
    for tick in tickers:
        urls = [f'https://finance.yahoo.com/quote/{tick}/history?p={tick}',
                f'https://finance.yahoo.com/quote/{tick}/history?period1=1582588800&period2=1601596800&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true',
                f'https://finance.yahoo.com/quote/{tick}/history?period1=1577923200&period2=1589414400&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true',]

        for url in urls[::-1]:   
            html = requests.get(url).text
            soup = BeautifulSoup(html, 'lxml')
            tables = soup.find_all('tr', attrs={'class': "BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"})


            for i in range(len(tables)):
                curr_table = tables[::-1][i]
                curr_data = [x.text for x in curr_table.find_all('td')] + [tick]
                if '-' in curr_data:
                    continue
                if len(curr_data) != 8:
                    continue                        
                curr_data.pop(5)

                # Change str values to floats/ints.
                for j in range(1,5):
                    
                    curr_data[j] = float(curr_data[j].replace(',', ''))

                curr_data[5] = curr_data[5].replace(',', '')
                try:
                    curr_data[5] = int(curr_data[5])
                except ValueError:
                    continue

                if (curr_data[0], curr_data[5]) in zip(df['Date'], df['Ticker']):
                    break
                else:
                    df.loc[df.shape[0]] = curr_data
                    
        if verbose==1:            
            print(f'Ticker: {tick}, {tickers.index(tick)+1} out of {len(tickers)} completed')
                    
    return df

# %%
health_care_data = get_df(tickers, verbose=1)
# Out:
# Ticker: ABCL, 1 out of 159 completed
# Ticker: MRVI, 2 out of 159 completed
# Ticker: ACAD, 3 out of 159 completed
# Ticker: NVTA, 4 out of 159 completed
# Ticker: SGFY, 5 out of 159 completed
# Ticker: RCM, 6 out of 159 completed
# Ticker: SHC, 7 out of 159 completed
# Ticker: CHNG, 8 out of 159 completed
# Ticker: GTBIF, 9 out of 159 completed
# Ticker: EXEL, 10 out of 159 completed
# Ticker: ONEM, 11 out of 159 completed
# Ticker: HALO, 12 out of 159 completed
# Ticker: NVST, 13 out of 159 completed
# Ticker: TGTX, 14 out of 159 completed
# Ticker: PACB, 15 out of 159 completed
# Ticker: SANA, 16 out of 159 completed
# Ticker: APHA, 17 out of 159 completed
# Ticker: AMWL, 18 out of 159 completed
# Ticker: PRGO, 19 out of 159 completed
# Ticker: IOVA, 20 out of 159 completed
# Ticker: CERT, 21 out of 159 completed
# Ticker: CVET, 22 out of 159 completed
# Ticker: ALLO, 23 out of 159 completed
# Ticker: FGEN, 24 out of 159 completed
# Ticker: SDC, 25 out of 159 completed
# Ticker: PINC, 26 out of 159 completed
# Ticker: OCDX, 27 out of 159 completed
# Ticker: NKTR, 28 out of 159 completed
# Ticker: AHCO, 29 out of 159 completed
# Ticker: TLRY, 30 out of 159 completed
# Ticker: INOV, 31 out of 159 completed
# Ticker: CRON, 32 out of 159 completed
# Ticker: INSM, 33 out of 159 completed
# Ticker: RLAY, 34 out of 159 completed
# Ticker: APLS, 35 out of 159 completed
# Ticker: BFLY, 36 out of 159 completed
# Ticker: PGNY, 37 out of 159 completed
# Ticker: NK, 38 out of 159 completed
# Ticker: OPCH, 39 out of 159 completed
# Ticker: RVMD, 40 out of 159 completed
# Ticker: AGIO, 41 out of 159 completed
# Ticker: HMSY, 42 out of 159 completed
# Ticker: FOLD, 43 out of 159 completed
# Ticker: CRLBF, 44 out of 159 completed
# Ticker: ALKS, 45 out of 159 completed
# Ticker: PDCO, 46 out of 159 completed
# Ticker: CORT, 47 out of 159 completed
# Ticker: ITCI, 48 out of 159 completed
# Ticker: EDIT, 49 out of 159 completed
# Ticker: GBT, 50 out of 159 completed
# Ticker: OMI, 51 out of 159 completed
# Ticker: MDRX, 52 out of 159 completed
# Ticker: ACCD, 53 out of 159 completed
# Ticker: INO, 54 out of 159 completed
# Ticker: MYGN, 55 out of 159 completed
# Ticker: RCUS, 56 out of 159 completed
# Ticker: TRSSF, 57 out of 159 completed
# Ticker: VCEL, 58 out of 159 completed
# Ticker: ACB, 59 out of 159 completed
# Ticker: HCSG, 60 out of 159 completed
# Ticker: NNOX, 61 out of 159 completed
# Ticker: PBH, 62 out of 159 completed
# Ticker: MD, 63 out of 159 completed
# Ticker: DRNA, 64 out of 159 completed
# Ticker: MYOV, 65 out of 159 completed
# Ticker: AXNX, 66 out of 159 completed
# Ticker: BLUE, 67 out of 159 completed
# Ticker: BCRX, 68 out of 159 completed
# Ticker: ORGO, 69 out of 159 completed
# Ticker: GBIO, 70 out of 159 completed
# Ticker: VOR, 71 out of 159 completed
# Ticker: AUPH, 72 out of 159 completed
# Ticker: KURA, 73 out of 159 completed
# Ticker: EVH, 74 out of 159 completed
# Ticker: YI, 75 out of 159 completed
# Ticker: SAVA, 76 out of 159 completed
# Ticker: ZYME, 77 out of 159 completed
# Ticker: TBIO, 78 out of 159 completed
# Ticker: MCRB, 79 out of 159 completed
# Ticker: HRTX, 80 out of 159 completed
# Ticker: SGMO, 81 out of 159 completed
# Ticker: QURE, 82 out of 159 completed
# Ticker: IMVT, 83 out of 159 completed
# Ticker: LMNX, 84 out of 159 completed
# Ticker: SY, 85 out of 159 completed
# Ticker: SUPN, 86 out of 159 completed
# Ticker: ALEC, 87 out of 159 completed
# Ticker: CDXS, 88 out of 159 completed
# Ticker: ATRA, 89 out of 159 completed
# Ticker: GNMK, 90 out of 159 completed
# Ticker: CYTK, 91 out of 159 completed
# Ticker: OCUL, 92 out of 159 completed
# Ticker: MGNX, 93 out of 159 completed
# Ticker: RYTM, 94 out of 159 completed
# Ticker: LNTH, 95 out of 159 completed
# Ticker: ATEC, 96 out of 159 completed
# Ticker: CNST, 97 out of 159 completed
# Ticker: MRSN, 98 out of 159 completed
# Ticker: ADVM, 99 out of 159 completed
# Ticker: OMER, 100 out of 159 completed
# Ticker: INVA, 101 out of 159 completed
# Ticker: CDMO, 102 out of 159 completed
# Ticker: PSNL, 103 out of 159 completed
# Ticker: CHRS, 104 out of 159 completed
# Ticker: ZGNX, 105 out of 159 completed
# Ticker: TRIL, 106 out of 159 completed
# Ticker: ATNX, 107 out of 159 completed
# Ticker: CDXC, 108 out of 159 completed
# Ticker: RAD, 109 out of 159 completed
# Ticker: SNDX, 110 out of 159 completed
# Ticker: CLDX, 111 out of 159 completed
# Ticker: FPRX, 112 out of 159 completed
# Ticker: KPTI, 113 out of 159 completed
# Ticker: ACRS, 114 out of 159 completed
# Ticker: VNDA, 115 out of 159 completed
# Ticker: ADAG, 116 out of 159 completed
# Ticker: HGEN, 117 out of 159 completed
# Ticker: TCRR, 118 out of 159 completed
# Ticker: VERU, 119 out of 159 completed
# Ticker: STRO, 120 out of 159 completed
# Ticker: BOLT, 121 out of 159 completed
# Ticker: VIVO, 122 out of 159 completed
# Ticker: AVXL, 123 out of 159 completed
# Ticker: COLL, 124 out of 159 completed
# Ticker: GTHX, 125 out of 159 completed
# Ticker: PRVB, 126 out of 159 completed
# Ticker: AERI, 127 out of 159 completed
# Ticker: APR, 128 out of 159 completed
# Ticker: OSUR, 129 out of 159 completed
# Ticker: LHDX, 130 out of 159 completed
# Ticker: ICPT, 131 out of 159 completed
# Ticker: CVM, 132 out of 159 completed
# Ticker: PETS, 133 out of 159 completed
# Ticker: ESPR, 134 out of 159 completed
# Ticker: BVS, 135 out of 159 completed
# Ticker: GRTS, 136 out of 159 completed
# Ticker: DTIL, 137 out of 159 completed
# Ticker: ALT, 138 out of 159 completed
# Ticker: KALV, 139 out of 159 completed
# Ticker: OXFD, 140 out of 159 completed
# Ticker: FLXN, 141 out of 159 completed
# Ticker: MRNS, 142 out of 159 completed
# Ticker: ALDX, 143 out of 159 completed
# Ticker: RVP, 144 out of 159 completed
# Ticker: LABP, 145 out of 159 completed
# Ticker: NEXI, 146 out of 159 completed
# Ticker: ZYXI, 147 out of 159 completed
# Ticker: SNSE, 148 out of 159 completed
# Ticker: CRMD, 149 out of 159 completed
# Ticker: FIXX, 150 out of 159 completed
# Ticker: AVRO, 151 out of 159 completed
# Ticker: DBTX, 152 out of 159 completed
# Ticker: CODX, 153 out of 159 completed
# Ticker: PBYI, 154 out of 159 completed
# Ticker: GLSI, 155 out of 159 completed
# Ticker: EOLS, 156 out of 159 completed
# Ticker: TLIS, 157 out of 159 completed
# Ticker: CLVR, 158 out of 159 completed
# Ticker: ENLV, 159 out of 159 completed

# %%
health_care_data.to_csv('HealthcareStockFeb2021.csv')
